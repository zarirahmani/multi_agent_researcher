# %% [markdown]
# ## Create Agents to Research and Write an Article

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# First install these libraries:

# %% [markdown]
# pip install crewai==0.28.8 crewai_tools==0.1.6 langchain_community==0.0.29

# %%
from crewai import Agent, Task, Crew
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from crewai import Agent, Task, Crew
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/__init__.py:1
# ----> 1 from crewai.agent import Agent
#       2 from crewai.crew import Crew
#       3 from crewai.process import Process
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/agent.py:23
#      11 from pydantic import (
#      12     UUID4,
#      13     BaseModel,
#    (...)     19     model_validator,
#      20 )
#      21 from pydantic_core import PydanticCustomError
# ---> 23 from crewai.agents import CacheHandler, CrewAgentExecutor, CrewAgentParser, ToolsHandler
#      24 from crewai.memory.contextual.contextual_memory import ContextualMemory
#      25 from crewai.utilities import I18N, Logger, Prompts, RPMController
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/agents/__init__.py:2
#       1 from .cache.cache_handler import CacheHandler
# ----> 2 from .executor import CrewAgentExecutor
#       3 from .parser import CrewAgentParser
#       4 from .tools_handler import ToolsHandler
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/agents/executor.py:19
#      17 from crewai.memory.long_term.long_term_memory_item import LongTermMemoryItem
#      18 from crewai.memory.short_term.short_term_memory_item import ShortTermMemoryItem
# ---> 19 from crewai.tools.tool_usage import ToolUsage, ToolUsageErrorException
#      20 from crewai.utilities import I18N
#      21 from crewai.utilities.converter import ConverterError
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/tools/tool_usage.py:9
#       6 from langchain_openai import ChatOpenAI
#       8 from crewai.agents.tools_handler import ToolsHandler
# ----> 9 from crewai.telemetry import Telemetry
#      10 from crewai.tools.tool_calling import InstructorToolCalling, ToolCalling
#      11 from crewai.utilities import I18N, Converter, ConverterError, Printer
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/telemetry/__init__.py:1
# ----> 1 from .telemetry import Telemetry
#
# File /workspaces/Multi-Agent-Researcher-/venv/lib/python3.12/site-packages/crewai/telemetry/telemetry.py:7
#       4 import platform
#       5 from typing import Any
# ----> 7 import pkg_resources
#       8 from opentelemetry import trace
#       9 from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
#
# ModuleNotFoundError: No module named 'pkg_resources'
